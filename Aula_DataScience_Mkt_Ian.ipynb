# %% [markdown]
# <a href="https://colab.research.google.com/github/ianvogel-glitch/Datascience_mkt/blob/main/Aula_DataScience_Mkt_Ian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ian Roscoe Bessa Vogel

# %% [markdown]
# 09/09/2026
#
# Conhecendo os Frameworks e pacotes utilizados em Ciência de Dados _ Introdução ao Python, NumPy e Pandas
# Aula prática | Instalação ambiente Python | Exercício prático
#
# (Práticas com Python (Marketing Digital) https://meet.google.com/xao-oeeh-tab) Link da aula prática.

# %%
'''
Meu primeiro codigo
'''


#Meu primeiro codigo


print("Meu primeiro codigo")
# Out:
# Meu primeiro codigo

# %%
valor_int = 3
valor_float = 1.5
valor_string = "Ola, mundo"
valor_bool = True

print(valor_int)
print(valor_float)
print(valor_string)
print(valor_bool)
# Out:
# 3
# 1.5
# Ola, mundo
# True

# %%
a = 100
b = str(a)
print(b)
print(type(b))

c = 12.0
d = int(c)
print(d)
print(type(d))
# Out:
# 100
# <class 'str'>
# 12
# <class 'int'>

# %% [markdown]
# Aula 2 - 16/09 Manipulação de Dados
#
# Unidade 4

# %%
import pandas as pd

# %%
import pandas as pd
cidades = pd.DataFrame(
    [
        ["Paraná", "Londrina", 575377, 1356.00],
        ["São Paulo", "São Carlos", 254484, 1508.00],
        ["Santa Catarina", "Florianópolis", 508826, 1798.00],
        ["Paraná", "Curitiba", 1963726, 2293.00],
        ["São Paulo", "Campinas", 1223237, 1710.00]
    ], columns = ["Estado", "Cidade do Estado","Habitantes", "Salario-Medio"])
cidades
# Out:
#            Estado Cidade do Estado  Habitantes  Salario-Medio
# 0          Paraná         Londrina      575377         1356.0
# 1       São Paulo       São Carlos      254484         1508.0
# 2  Santa Catarina    Florianópolis      508826         1798.0
# 3          Paraná         Curitiba     1963726         2293.0
# 4       São Paulo         Campinas     1223237         1710.0

# %%
df = pd.read_csv("qualidade_vinho.csv", sep = ",", header=0)
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3716/130981813.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("qualidade_vinho.csv", sep = ",", header=0)
#       2 df.head(2)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'qualidade_vinho.csv'

# %%
cidades.head(2) # Retorna um novo dataframe com as n primeiras amostras
# Out:
#       Estado Cidade do Estado  Habitantes  Salario-Medio
# 0     Paraná         Londrina      575377         1356.0
# 1  São Paulo       São Carlos      254484         1508.0

# %%
cidades.tail(2) # Retorna um novo dataframe com as n últimas amostras
# Out:
#       Estado Cidade do Estado  Habitantes  Salario-Medio
# 3     Paraná         Curitiba     1963726         2293.0
# 4  São Paulo         Campinas     1223237         1710.0

# %%
cidades.shape # Retorna uma tupla com o número de linhas e colunas
# Out:
# (5, 4)

# %%
cidades.shape # Retorna uma tupla com o número de linhas e colunas
# Out:
# (5, 4)

# %%
cidades.info() # Retorna vazio e imprime na tela as informações gerais do dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Estado            5 non-null      object
#  1   Cidade do Estado  5 non-null      object
#  2   Habitantes        5 non-null      int64
#  3   Salario-Medio     5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
cidades.columns # Retorna uma lista com o nome de todas as colunas
# Out:
# Index(['Estado', 'Cidade do Estado', 'Habitantes', 'Salario-Medio'], dtype='object')

# %%
cidades['Salário-Médio'].describe() # Retorna um objeto DataFrame com as medidas estatísticas para cada coluna
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salário-Médio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3716/2896922047.py in <cell line: 0>()
# ----> 1 cidades['Salário-Médio'].describe() # Retorna um objeto DataFrame com as medidas estatísticas para cada coluna
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Salário-Médio'

# %% [markdown]
# Tipos de Dados com Pandas

# %%
cidades.dtypes
cidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Estado            5 non-null      object
#  1   Cidade do Estado  5 non-null      object
#  2   Habitantes        5 non-null      int64
#  3   Salario-Medio     5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
cidades['Habitantes'] = cidades['Habitantes'].astype('float64')
cidades.dtypes
# Out:
# Estado               object
# Cidade do Estado     object
# Habitantes          float64
# Salario-Medio       float64
# dtype: object

# %%
cidades['Data'] = ['3-8-2021', '3-9-2021', '3-10-2021', '3-11-2021', '3-12-2021']

cidades['Data'] = pd.to_datetime(cidades['Data'], format='%d-%m-%Y') # Dia, Mês, Ano

cidades
# Out:
#            Estado Cidade do Estado  Habitantes  Salario-Medio       Data
# 0          Paraná         Londrina    575377.0         1356.0 2021-08-03
# 1       São Paulo       São Carlos    254484.0         1508.0 2021-09-03
# 2  Santa Catarina    Florianópolis    508826.0         1798.0 2021-10-03
# 3          Paraná         Curitiba   1963726.0         2293.0 2021-11-03
# 4       São Paulo         Campinas   1223237.0         1710.0 2021-12-03

# %%
cidades['Data'] = cidades['Data'].dt.strftime('%d-%m-%Y') # Dia, Mês, Ano
cidades # Novo Formato
# Out:
#            Estado Cidade do Estado  Habitantes  Salario-Medio        Data
# 0          Paraná         Londrina    575377.0         1356.0  03-08-2021
# 1       São Paulo       São Carlos    254484.0         1508.0  03-09-2021
# 2  Santa Catarina    Florianópolis    508826.0         1798.0  03-10-2021
# 3          Paraná         Curitiba   1963726.0         2293.0  03-11-2021
# 4       São Paulo         Campinas   1223237.0         1710.0  03-12-2021

# %% [markdown]
# Renomeando Colunas

# %%
cidades.rename(columns={'Habitantes': 'N Habitantes', 'Data': 'Data - Censo'}, inplace=True)
cidades
# Out:
#            Estado Cidade do Estado  N Habitantes  Salario-Medio Data - Censo
# 0          Paraná         Londrina      575377.0         1356.0   03-08-2021
# 1       São Paulo       São Carlos      254484.0         1508.0   03-09-2021
# 2  Santa Catarina    Florianópolis      508826.0         1798.0   03-10-2021
# 3          Paraná         Curitiba     1963726.0         2293.0   03-11-2021
# 4       São Paulo         Campinas     1223237.0         1710.0   03-12-2021

# %% [markdown]
# Selecionando Linhas e Colunas

# %%
cidadesHab = cidades[['N Habitantes', 'Salário-Médio']] # Seleciona as duas colunas com os nomes especificados
cidadesHab
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3716/3643831914.py in <cell line: 0>()
# ----> 1 cidadesHab = cidades[['N Habitantes', 'Salário-Médio']] # Seleciona as duas colunas com os nomes especificados
#       2 cidadesHab
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['Salário-Médio'] not in index"

# %%
cidades.loc[[1, 2]] # Seleciona as duas linhas com os nomes especificados (note que o "rótulo" de cada linha está presente na forma de números inteiros)
# Out:
#            Estado Cidade do Estado  N Habitantes  Salario-Medio Data - Censo
# 1       São Paulo       São Carlos      254484.0         1508.0   03-09-2021
# 2  Santa Catarina    Florianópolis      508826.0         1798.0   03-10-2021

# %%
cidades.iloc[1:3] # Seleciona as linhas do dataframe original, referentes ao índice determinado
# Out:
#            Estado Cidade do Estado  N Habitantes  Salario-Medio Data - Censo
# 1       São Paulo       São Carlos      254484.0         1508.0   03-09-2021
# 2  Santa Catarina    Florianópolis      508826.0         1798.0   03-10-2021

# %%
cidades.iloc[:, 0:2] # Seleciona todas as linhas e as duas primeiras colunas do dataframe original
# Out:
#            Estado Cidade do Estado
# 0          Paraná         Londrina
# 1       São Paulo       São Carlos
# 2  Santa Catarina    Florianópolis
# 3          Paraná         Curitiba
# 4       São Paulo         Campinas

# %%
cidades.iloc[1:3, :3] # Seleciona as duas primeiras linhas e as três primeiras colunas
# Out:
#            Estado Cidade do Estado  N Habitantes
# 1       São Paulo       São Carlos      254484.0
# 2  Santa Catarina    Florianópolis      508826.0

# %%
cidades.iloc[:, [1, 3, 0, 2]] # Seleciona todas as linhas e as colunas determinadas
# Out:
#   Cidade do Estado  Salario-Medio          Estado  N Habitantes
# 0         Londrina         1356.0          Paraná      575377.0
# 1       São Carlos         1508.0       São Paulo      254484.0
# 2    Florianópolis         1798.0  Santa Catarina      508826.0
# 3         Curitiba         2293.0          Paraná     1963726.0
# 4         Campinas         1710.0       São Paulo     1223237.0

# %% [markdown]
# Adicionando e Removendo Colunas

# %%
cidades.insert(2, 'Sigla', ['PR', 'SP', 'SC', 'PR', 'SP']) # Adiciona novos dados no índice dois
cidades.insert(2, 'Sigla-Repetida', cidades['Sigla']) # Adiciona uma coluna repetida "Sigla"
cidades
# Out:
#            Estado Cidade do Estado Sigla-Repetida Sigla  N Habitantes  \
# 0          Paraná         Londrina             PR    PR      575377.0
# 1       São Paulo       São Carlos             SP    SP      254484.0
# 2  Santa Catarina    Florianópolis             SC    SC      508826.0
# 3          Paraná         Curitiba             PR    PR     1963726.0
# 4       São Paulo         Campinas             SP    SP     1223237.0
#
#    Salario-Medio Data - Censo
# 0         1356.0   03-08-2021
# 1         1508.0   03-09-2021
# 2         1798.0   03-10-2021
# 3         2293.0   03-11-2021
# 4         1710.0   03-12-2021

# %%
cidades.pop('Sigla-Repetida')

# ou

cidades = cidades.drop(['Sigla-Repetida'], axis=1)
cidades
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3716/3673162480.py in <cell line: 0>()
#       3 # ou
#       4
# ----> 5 cidades = cidades.drop(['Sigla-Repetida'], axis=1)
#       6 cidades
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Sigla-Repetida'] not found in axis"

# %% [markdown]
# Operações Básicas - Consultas

# %%
cidades.query('`Salário-Médio` > 1400.0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.13/collections/__init__.py in __getitem__(self, key)
#    1021                 pass
# -> 1022         return self.__missing__(key)            # support subclasses that define __missing__
#    1023
#
# /usr/lib/python3.13/collections/__init__.py in __missing__(self, key)
#    1013     def __missing__(self, key):
# -> 1014         raise KeyError(key)
#    1015
#
# KeyError: 'BACKTICK_QUOTED_STRING_Salário_MINUS_Médio'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     241                 # e.g., df[df > 0]
# --> 242                 return self.temps[key]
#     243             except KeyError as err:
#
# KeyError: 'BACKTICK_QUOTED_STRING_Salário_MINUS_Médio'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /tmp/ipykernel_3716/1854125968.py in <cell line: 0>()
# ----> 1 cidades.query('`Salário-Médio` > 1400.0')
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4947         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4948
# -> 4949         return _eval(expr, inplace=inplace, **kwargs)
#    4950
#    4951     def select_dtypes(self, include=None, exclude=None) -> Self:
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     334         )
#     335
# --> 336         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     337
#     338         if engine == "numexpr" and (
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     803         self.parser = parser
#     804         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 805         self.terms = self.parse()
#     806
#     807     @property
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in parse(self)
#     822         Parse an expression.
#     823         """
# --> 824         return self._visitor.visit(self.expr)
#     825
#     826     @property
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = f"visit_{type(node).__name__}"
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     415             raise SyntaxError("only a single expression is allowed")
#     416         expr = node.body[0]
# --> 417         return self.visit(expr, **kwargs)
#     418
#     419     def visit_Expr(self, node, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = f"visit_{type(node).__name__}"
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     418
#     419     def visit_Expr(self, node, **kwargs):
# --> 420         return self.visit(node.value, **kwargs)
#     421
#     422     def _rewrite_membership_op(self, node, left, right):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = f"visit_{type(node).__name__}"
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     713             op = self.translate_In(ops[0])
#     714             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 715             return self.visit(binop)
#     716
#     717         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = f"visit_{type(node).__name__}"
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     529
#     530     def visit_BinOp(self, node, **kwargs):
# --> 531         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     532         left, right = self._maybe_downcast_constants(left, right)
#     533         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     449     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     450         if left is None:
# --> 451             left = self.visit(node.left, side="left")
#     452         if right is None:
#     453             right = self.visit(node.right, side="right")
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = f"visit_{type(node).__name__}"
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     539
#     540     def visit_Name(self, node, **kwargs) -> Term:
# --> 541         return self.term_type(node.id, self.env, **kwargs)
#     542
#     543     # TODO(py314): deprecated since Python 3.8. Remove after Python 3.14 is min
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      89         tname = str(name)
#      90         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91         self._value = self._resolve_name()
#      92         self.encoding = encoding
#      93
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/ops.py in _resolve_name(self)
#     113             is_local = False
#     114
# --> 115         res = self.env.resolve(local_name, is_local=is_local)
#     116         self.update(res)
#     117
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     242                 return self.temps[key]
#     243             except KeyError as err:
# --> 244                 raise UndefinedVariableError(key, is_local) from err
#     245
#     246     def swapkey(self, old_key: str, new_key: str, new_value=None) -> None:
#
# UndefinedVariableError: name 'BACKTICK_QUOTED_STRING_Salário_MINUS_Médio' is not defined

# %%
cidades.query('Estado == "São Paulo"')
# Out:
#       Estado Cidade do Estado Sigla  N Habitantes  Salario-Medio Data - Censo
# 1  São Paulo       São Carlos    SP      254484.0         1508.0   03-09-2021
# 4  São Paulo         Campinas    SP     1223237.0         1710.0   03-12-2021

# %%
cidades.query('`N Habitantes` > 500000 and `N Habitantes` < 1300000')
# Out:
#            Estado Cidade do Estado Sigla  N Habitantes  Salario-Medio  \
# 0          Paraná         Londrina    PR      575377.0         1356.0
# 2  Santa Catarina    Florianópolis    SC      508826.0         1798.0
# 4       São Paulo         Campinas    SP     1223237.0         1710.0
#
#   Data - Censo
# 0   03-08-2021
# 2   03-10-2021
# 4   03-12-2021

# %% [markdown]
# Operações Básicas - Ordenação

# %%
cidades_salarios = pd.DataFrame(
    [
        ['Paraná', 'Londrina', 1356.00],
        ['São Paulo', 'São Carlos', 1508.00],
        ['Santa Catarina', 'Florianópolis', 1798.00],
        ['Paraná', 'Curitiba', 2293.00],
        ['São Paulo', 'Campinas', 1710.00]
    ], columns=['Estado', 'Cidade', 'Salário-Médio'])

cidades_salarios
# Out:
#            Estado         Cidade  Salário-Médio
# 0          Paraná       Londrina         1356.0
# 1       São Paulo     São Carlos         1508.0
# 2  Santa Catarina  Florianópolis         1798.0
# 3          Paraná       Curitiba         2293.0
# 4       São Paulo       Campinas         1710.0

# %%
cidades_pop = pd.DataFrame(
    [
        ['Londrina', 575377],
        ['São Carlos', 254484],
        ['Florianópolis', 508826],
        ['Curitiba', 1963726],
        ['Campinas', 1223237]
    ], columns=['Cidade', 'Habitantes'])

cidades_pop
# Out:
#           Cidade  Habitantes
# 0       Londrina      575377
# 1     São Carlos      254484
# 2  Florianópolis      508826
# 3       Curitiba     1963726
# 4       Campinas     1223237

# %%
pd.merge(left=cidades_salarios, right=cidades_pop, on="Cidade")
# Out:
#            Estado         Cidade  Salário-Médio  Habitantes
# 0          Paraná       Londrina         1356.0      575377
# 1       São Paulo     São Carlos         1508.0      254484
# 2  Santa Catarina  Florianópolis         1798.0      508826
# 3          Paraná       Curitiba         2293.0     1963726
# 4       São Paulo       Campinas         1710.0     1223237

# %%
pd.merge(left=cidades_salarios, right=cidades_pop, on="Cidade", how="outer")
# Out:
#            Estado         Cidade  Salário-Médio  Habitantes
# 0       São Paulo       Campinas         1710.0     1223237
# 1          Paraná       Curitiba         2293.0     1963726
# 2  Santa Catarina  Florianópolis         1798.0      508826
# 3          Paraná       Londrina         1356.0      575377
# 4       São Paulo     São Carlos         1508.0      254484

# %%
cidades_df1 = pd.DataFrame(
    [
        ['Londrina', 575377],
        ['São Carlos', 254484],
        ['Florianópolis', 508826],
    ], columns=['Cidade', 'Habitantes'])

cidades_df1
# Out:
#           Cidade  Habitantes
# 0       Londrina      575377
# 1     São Carlos      254484
# 2  Florianópolis      508826

# %%
cidades_df2 = pd.DataFrame(
    [
        ['Curitiba', 1963726],
        ['Campinas', 1223237]
    ], columns=['Cidade', 'Habitantes'])

cidades_df2
# Out:
#      Cidade  Habitantes
# 0  Curitiba     1963726
# 1  Campinas     1223237

# %%
pd.concat([cidades_df1, cidades_df2], ignore_index=True)
# Out:
#           Cidade  Habitantes
# 0       Londrina      575377
# 1     São Carlos      254484
# 2  Florianópolis      508826
# 3       Curitiba     1963726
# 4       Campinas     1223237

# %% [markdown]
# Operações Básicas - Salvando DataFrames

# %%
cidades.to_csv("my_df.csv")
cidades.to_html("my_df.html")
cidades.to_json("my_df.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3716/1427583.py in <cell line: 0>()
# ----> 1 cidades.to_csv("my_df.csv")
#       2 cidades.to_html("my_df.html")
#       3 cidades.to_json("my_df.json")
#
# NameError: name 'cidades' is not defined
